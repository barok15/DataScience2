# %%
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('ETdata.csv')

# %%
df
# Out:
#           Country  Year      Status  \
# 0     Afghanistan  2015  Developing
# 1     Afghanistan  2014  Developing
# 2     Afghanistan  2013  Developing
# 3     Afghanistan  2012  Developing
# 4     Afghanistan  2011  Developing
# ...           ...   ...         ...
# 2933     Zimbabwe  2004  Developing
# 2934     Zimbabwe  2003  Developing
# 2935     Zimbabwe  2002  Developing
# 2936     Zimbabwe  2001  Developing
# 2937     Zimbabwe  2000  Developing
#
#       Adult Mortality (probability of dying between 15 and 60 years per 1000 people)  \
# 0                                                 263.0
# 1                                                 271.0
# 2                                                 268.0
# 3                                                 272.0
# 4                                                 275.0
# ...                                                 ...
# 2933                                              723.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 18 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Country                                                                         2938 non-null   object
#  1   Year                                                                            2938 non-null   int64
#  2   Status                                                                          2938 non-null   object
#  3   Adult Mortality (probability of dying between 15 and 60 years per 1000 people)  2928 non-null   float64
#  4   Infant Deaths (number of infant deaths per 1000 people)                         2938 non-null   int64
#  5   Alcohol (average number of litres consumed by a person)                         2744 non-null   float64
# ...

# %%
sns.scatterplot(data=df, x='Schooling (average number of years completed)', y='Life Expectancy (Years)')
# Out:
# <AxesSubplot:xlabel='Schooling (average number of years completed)', ylabel='Life Expectancy (Years)'>

# %%
df_train, df_test = train_test_split(df, test_size=0.3)

# %%
def train(df_train):
    # y = mx+b
    # b = 0 
    
    X_train = df_train[['Schooling (average number of years completed)']]
    y_train = df_train['Life Expectancy (Years)']

    # Calculate the average change in life expectancy for a one-unit change in schooling
    average_slope = y_train.mean() / X_train.mean()

    return average_slope

# %%
#US 2023 
# schooling = 13.5 years 
schooling_us_2023 = 13.3  # Assume 13.3 years of schooling

# Coefficients and intercept obtained from the trained model
slope = train(df_train)

print(slope)

life_US_2023 = (slope*schooling_us_2023)
print(life_US_2023)
# Out:
# Schooling (average number of years completed)    5.795119
# dtype: float64
# Schooling (average number of years completed)    77.07508
# dtype: float64

# %%
# Out:
# Schooling (average number of years completed)   NaN
# dtype: float64
